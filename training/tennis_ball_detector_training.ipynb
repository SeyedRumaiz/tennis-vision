# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 1.9 MB/s  0:00:29m0:00:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 2.4 MB/s  0:00:01 eta 0:00:01
# ...
#   Attempting uninstall: idna╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#     Found existing installation: idna 3.18m━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#     Uninstalling idna-3.18:m╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#       Successfully uninstalled idna-3.1890m━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [roboflow]7/8 [roboflow]-headless]
# ...

# %% [markdown]
# # Pull Dataset

# %%
from roboflow import Roboflow

# Initialize Roboflow object with the API key from roboflow.
rf = Roboflow(api_key="gRfkFUiZfjROOuohtClj")

# Select project and version
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil   # File management
import os

# %%
print(os.listdir("tennis-ball-detection-6"))
# Out:
# ['README.roboflow.txt', 'tennis-ball-detection-6', 'README.dataset.txt', 'data.yaml']

# %%
# Move training folder
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)

# Move test folder
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)

# Move validation folder
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/shutil.py:806, in move(src, dst, copy_function)
#     805 try:
# --> 806     os.rename(src, real_dst)
#     807 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tennis-ball-detection-6/train' -> 'tennis-ball-detection-6/tennis-ball-detection-6/train/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Move training folder
# ----> 2 shutil.move("tennis-ball-detection-6/train",
#       3 "tennis-ball-detection-6/tennis-ball-detection-6/train",
#       4 )
#       6 # Move test folder
#       7 shutil.move("tennis-ball-detection-6/test",
# ...

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# /Users/seyedrumaiz/Desktop/tennis_analysis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Ultralytics 8.4.75 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1)
# ...
